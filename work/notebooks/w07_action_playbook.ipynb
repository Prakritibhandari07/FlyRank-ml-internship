# %% [markdown]
# # ML-10 — Content Action Playbook
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Prakritibhandari07/FlyRank-ml-internship/blob/main/work/notebooks/w07_action_playbook.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Ranked actions + reason codes
#
# **Ranked Actions Queue**
#
# 1. [Action 1] → Reason: [Reason code, e.g., High CTR, low decay]
# 2. [Action 2] → Reason: [Reason code, e.g., Cost-effective, high engagement]
# 3. [Action 3] → Reason: [Reason code, e.g., Low ROI, recommend pause]
#
# **Notes:**
# - Each action is tied to an archetype.
# - Reason codes should be concise and human-readable.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import json

# Example ranked actions (replace with your model outputs)
actions = [
    {"rank": 1, "action": "Promote short-form video", "reason": "High CTR, low decay"},
    {"rank": 2, "action": "Refresh blog archetype A", "reason": "Engagement drops after 14 days"},
    {"rank": 3, "action": "Pause archetype B", "reason": "High cost, low return"},
]

queue_df = pd.DataFrame(actions)
queue_df
# Out:
#    rank                    action                          reason
# 0     1  Promote short-form video             High CTR, low decay
# 1     2  Refresh blog archetype A  Engagement drops after 14 days
# 2     3         Pause archetype B           High cost, low return

# %% [markdown]
# ## 2. Intended use and limits
#
# **Intended Use**
# - This playbook is for research recommendations only.
# - It guides content strategists on what to promote, refresh, or pause.
#
# **Limits**
# - Valid only for dataset: [Dataset name]
# - Timeframe: [Specify period]
# - Not generalizable to production systems.

# %%
# Example: store intended use and limits in a dict for traceability
intended_use = {
    "purpose": "Research recommendations only",
    "guidance": "Promote, refresh, or pause content archetypes",
    "dataset": "Dataset_X",   # replace with your dataset name
    "timeframe": "Q3 2026",   # replace with your timeframe
    "note": "Not generalizable to production systems"
}

intended_use
# Out:
# {'purpose': 'Research recommendations only',
#  'guidance': 'Promote, refresh, or pause content archetypes',
#  'dataset': 'Dataset_X',
#  'timeframe': 'Q3 2026',
#  'note': 'Not generalizable to production systems'}

# %% [markdown]
# ## 3. Human review + the no-go list
# **Human Review Rules**
# - All automated queues must be reviewed by a strategist before publishing.
# - Sensitive or brand-critical actions require explicit approval.
#
# **No-Go List (Do NOT Automate)**
# - Legal disclaimers
# - Brand-critical messaging
# - Sensitive topics (e.g., health, politics)

# %%
# Example: define human review rules and no-go list
human_review = {
    "rules": [
        "All automated queues must be reviewed by a strategist",
        "Sensitive or brand-critical actions require explicit approval"
    ],
    "no_go_list": [
        "Legal disclaimers",
        "Brand-critical messaging",
        "Sensitive topics (health, politics)"
    ]
}

human_review
# Out:
# {'rules': ['All automated queues must be reviewed by a strategist',
#   'Sensitive or brand-critical actions require explicit approval'],
#  'no_go_list': ['Legal disclaimers',
#   'Brand-critical messaging',
#   'Sensitive topics (health, politics)']}

# %% [markdown]
# ## 4. Monitoring / retrain triggers
#
# **Monitoring**
# - Track weekly CTR decay.
# - Monitor archetype distribution shifts.
#
# **Retrain Triggers**
# - Retrain if CTR drops >15% week-over-week.
# - Retrain if archetype distribution shifts >20%.

# %%
# Example: monitoring and retrain triggers stored in a dict
monitoring_plan = {
    "monitoring": [
        "Track weekly CTR decay",
        "Monitor archetype distribution shifts"
    ],
    "retrain_triggers": [
        "Retrain if CTR drops >15% week-over-week",
        "Retrain if archetype distribution shifts >20%"
    ]
}

monitoring_plan
# Out:
# {'monitoring': ['Track weekly CTR decay',
#   'Monitor archetype distribution shifts'],
#  'retrain_triggers': ['Retrain if CTR drops >15% week-over-week',
#   'Retrain if archetype distribution shifts >20%']}

# %% [markdown]
# ## 5. Exports for the paper
#
# # Export ranked queue
# queue_df.to_csv("../outputs/action_queue.csv", index=False)
#
# # Save figures
# fig.savefig("../figures/decay_curve.png")
#
# # Save metrics receipts
# with open("../outputs/metrics.json", "w") as f:
#     json.dump(metrics, f)

# %%
import os

# Make sure outputs and figures directories exist
os.makedirs("../outputs", exist_ok=True)
os.makedirs("../figures", exist_ok=True)

# Export ranked queue
queue_df.to_csv("../outputs/action_queue.csv", index=False)

# Example figure: decay curve (replace with your own plot)
decay_days = [1, 3, 7, 14, 21]
engagement = [100, 80, 60, 40, 25]

plt.plot(decay_days, engagement, marker="o")
plt.title("Content Engagement Decay Curve")
plt.xlabel("Days since publish")
plt.ylabel("Engagement (%)")
plt.grid(True)
plt.savefig("../figures/decay_curve.png")

# Example metrics receipts
metrics = {"CTR_mean": 0.12, "Decay_half_life_days": 10}
with open("../outputs/metrics.json", "w") as f:
    json.dump(metrics, f)

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
